# %% [markdown]
# # Data Basics
#
# Written By: Aiden Zelakiewicz (asz39@cornell.edu) & Abigail Bohl (acb338@cornell.edu)
#
# Inspired By: [Python Bootcamp](https://github.com/Shockblack/Python_Bootcamp) by Aiden Zelakiewicz and tOSU ASTRO1221 HW02 by [Prof. Donald Terndrup](https://astronomy.osu.edu/people/terndrup.1)
#
# In this notebook, we will be using the [NASA Exoplanet Archive (NEA)](https://exoplanetarchive.ipac.caltech.edu/) to learn how to read in data, manipulate it, and plot it. The NEA is a database maintained by Caltech/IPAC and NASA of confirmed exoplanets and their published properties. We will be using the [NEA Planetary Systems Composite Data Table](https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=PSCompPars), which is a compilation of parameters from multiple literature sources for each planet. This specific table is a good starting point for statistical studies of exoplanets, but should not be used for detailed analysis of individual targets.
#
# When you see a "<---TO DO--->" header in this notebook, that is an exercise for you to complete! If you are struggling and have questions, ask a neighbor or your instructors for help and we will lead you in the right direction :D
#
#
# ## Goal for This Exercise:
#
# Use NASA Exoplanet Archive data while learning how to
#
# 1. Import data
#
# 2. Create Functions
#
# 3. Use if/else Statements
#
# 4. Perform Operations on Data
#
# 5. Do Basic Plotting

# %% [markdown]
# ## 1. Acquiring and Importing NEA Data
#
# Visit the NASA Exoplanet Archive [Planetary Systems Composite Data Table](https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=PSCompPars) and download the data as a CSV file. Save it under the `data` folder in this repository and either take note of the file name or rename it to something else, such as `nea_data.csv`.

# %% [markdown]
# ### Using Pandas to Read and Manipulate Data
#
# Reading data into Python natively can be a pain, especially if you have large datasets with different data types. Luckily, there are many packages like `pandas` and `numpy` that can help you read in data and manipulate it easily.
#
# `pandas` is a package which has become increasingly popular in data science recently due to its easy-to-use and intuitive `DataFrames`.
# Pandas `DataFrame`s are objects that are akin to fancy dictionaries (`dict`s).

# %%
# using pd as an alias for pandas is a common convention
import pandas as pd

# We need to get the filename + extension (.csv, .txt, .dat, etc.)
filename = "<PLACE NAME OF FILE HERE>"

# Strings can be denoted by either ' or "
file_path = 'data/' + filename

# Often pandas dataframes have the alias df
nea_df = pd.read_csv(file_path, sep=',', comment='#') # sep tells pandas how to split the data, ',' means split by commas

print("Type:", type(nea_df))

# We can print the column names and first few rows using the .head() method
# It's a useful way to get a quick look at the data and make sure it was read in correctly
print(nea_df.head())

# %% [markdown]
# You might have noticed when we printed the `head` of the NEA data that there are numerous columns with shorhand names that are not immediately obvious. The NEA data follows a specific organization structure, which is described in the [NEA Data Column Descriptions](https://exoplanetarchive.ipac.caltech.edu/docs/API_PS_columns.html) and at the top of the downloaded data file. Each column has a name, description, and unit. As a starting point for understanding the column names, any data column that starts with `pl_` is a planetary parameter, `st_` is a stellar parameter, and `sy_` is a system parameter. For example, the column `pl_rade` is the planetary radius in units of Earth radii, while `st_teff` is the stellar effective temperature in Kelvin.
#
# Let's see how to access specific columns and rows of the NEA data using `pandas`.
#
# > INDEXING
# >
# > In Python, indexing (denoted by brackets) starts at 0. So the first item of a dataset is index 0, the second item is index 1, and so on. If you have a list `my_list = [10, 20, 30]`, then `my_list[0]` will return `10`, `my_list[1]` will return `20`, and `my_list[2]` will return `30`. If you try to access an index that is out of range, such as `my_list[3]`, you will get an error.
# >
# > This is a common source of confusion for new programmers, so be careful when indexing into data!

# %%
# We can access columns by name
print(nea_df['pl_rade'], '\n') # \n is a newline character, just to make the output easier to read

# Or you can access rows by index using .iloc[row_index]
print(nea_df.iloc[0])

# %% [markdown]
# AWESOME! We now have our exoplanet data in a `pandas` `DataFrame` and we can start manipulating it. Now, what if we only want to look at planets that are smaller than 2 Earth radii? We can use a conditional statement to filter the data and view only the planets that meet our criteria.
#
# In Python, you can check whether things are greater than (`>`), less than (`<`), equal to (`==`), not equal to (`!=`), greater than or equal to (`>=`), or less than or equal to (`<=`) a certain value. For a list or array, this will give the location in the list where this condition is true or false (called a boolean array). Let's use this to find our terrestrial planets!

# %%
# Get the index of the rows where the planetary radius is less than 2 Earth radii
indices = nea_df['pl_rade'] < 2

# Use boolean array to filter
filtered_df = nea_df[indices]

# Print the filtered dataframe
print(filtered_df['pl_rade'].head())

# %% [markdown]
# ### If/Else Statements
#
# One of the most important logistical tools in coding is the `if` and `else` statement.
# These can be used to execute a chunk of code `if` a given condition is met or, if not, default to something `else`.
#
# `if`/`else` statements follow the same indentation rules as functions.
# The `if` condition is also set up using the following format: `if CONDITION:`.
# `else` does not require a condition though: `else:`. We can also stack conditions using operators like `and` as well as `or`, or set different cases to check using `elif`.
# `elif` falls in between `if` and `else`, and follows the same formatting as `if`.
#
# Let's grab the first planet in our NEA data and check if it is a terrestrial planet or not. We will define a terrestrial planet as one that has a radius less than 2 Earth radii.

# %%
# Grab the first planet
first_planet = nea_df.iloc[0]

if first_planet['pl_rade'] < 2:
    print("The first planet is a terrestrial planet with radius {:.2f} Earth radii.".format(first_planet['pl_rade']))
elif first_planet['pl_rade'] >= 2 and first_planet['pl_rade'] < 6:
    print("The first planet is a mini-Neptune with radius {:.2f} Earth radii.".format(first_planet['pl_rade']))
else:
    print("The first planet is GIANT with radius {:.2f} Earth radii.".format(first_planet['pl_rade']))

# %% [markdown]
# Awesome, we now have a way to check conditions and execute code based on those conditions! We also have a ton of stars in our catalogue which have temperatures and radii. We are going to want their luminosity by using Stefan-Boltzmann's Law to eventually compute the incident flux the planet recieves.
# $$
# L_* = 4 \pi R_*^2 \sigma T_{\rm eff}^4
# $$
# where $R_*$ is the stellar radius, $T_{\rm eff}$ is the stellar effective temperature, and $\sigma$ is the Stefan-Boltzmann constant. We can use this to compute the luminosity of each star in our catalogue and add it as a new column to our `DataFrame`. And let's do so using a function!
#
# ### Functions
#
# In Python, functions are declared using `def`.
# The format for creating a function is `def <function name>:`, where "\<function name\>" is relaced by a whatever you want to call your function.
# Function, and class, naming follows the same rules as variables.
#
# All code that you want included in the function must be indented so that Python knows it is part of the function, with the standard being to use a tab.
# Functions are usually closed using `return`, which can be used to output an object or just tell Python the function has ended.
#
#
# Functions should include documentation to explain what they do, called a docstring.
# Docstrings come immediately after the function declaration and are wrapped in three pairs of quotation marks (`"""DOCSTRING"""`).
# There are some common formatting styles for creating docstrings, but any kind of docstring is better than none!

# %%
# numpy is a package for numerical computing in Python
# It is often the first thing you import in any Python script
import numpy as np

def luminosity(R, T_eff):
    """
    Returns the luminosity of a star given its radius and effective temperature using the Stefan-Boltzmann law.

    Parameters
    ----------
    R : float
        radius of the star in solar radii
    T_eff : float
        effective temperature of the star in Kelvin

    Returns
    -------
    L : float
        luminosity of the star in Watts
    """
    # Above is a sample docstring in the numpy style, my personal favorite

    sigma_sb = 5.67e-8 # Stefan-Boltzmann constant in W/m^2/K^4
    R = R * 6.96e8 # convert radius from solar radii to meters

    L = 4 * np.pi * (R**2) * sigma_sb * (T_eff**4) # Stefan-Boltzmann law
    
    return L

# Compute the luminosity of the Sun
L_sun = luminosity(1, 5778) # radius in solar radii, temperature in Kelvin
print("Luminosity of the Sun: {:.2e} W".format(L_sun))

# %% [markdown]
# We can also compute the luminosities of all the stars by using the columns in our `DataFrame` and passing them to our function!

# %%
nea_luminosities = luminosity(nea_df['st_rad'], nea_df['st_teff'])

print(nea_luminosities.head())

# %% [markdown]
# We can add this as a new column to our `DataFrame` by calling a column with the name we want to give it and pass it the new array.

# %%
nea_df['luminosity'] = nea_luminosities

# %% [markdown]
# Let's say someone else is using a function you created by importing your file (like we did with `numpy` and `pandas`!) and they are confused about your organization.
# Someone can simply type `help()` with the function name to view the docstring.

# %%
help(luminosity)

# %% [markdown]
# Amazing, we've got some great tools at our disposal now!
# Let's get to the question at hand: what is the incident flux on each planet in our catalogue?
# The flux equation follows the inverse square law:
# $$
# F = \frac{L_*}{4 \pi d^2}
# $$
# where $L_*$ is the stellar luminosity and $d$ is the distance from the star to the planet.
#
# ### <---TO DO--->
# Above gives the flux in units of Watts per square meter, but we want to express the incident stellar flux (sometimes denoted by $S_{\rm eff}$ instead of $F$) in units of Earth flux, $S_{\rm \oplus}$.
# Modify the flux equation to express the flux in units of $S_{\rm \oplus}$ by:
# 1. Plug $L_*$ into the flux equation
# 2. Take the ratio of the flux from 1. to the flux received by Earth by pluggin in the variables for Earth (This will give you a new equation for $S_{\rm eff}$ where the stellar radius and effective temperature are in units of solar radius and solar effective temperature, respectively, and the orbital distance is in units of AU.)
# 3. Create a function that computes $S_{\rm eff}$ (you will use this later and in the HW!)
# 4. Compute the incident flux for all planets in the NEA catalogue and make a new column called `S_eff` in the `DataFrame` for it.
#
# > HINT: The orbital distance of the planet is given in the column `pl_orbsmax` in units of AU.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Basic Plotting
#
# `Matplotlib` is the most used plotting package within Python, with most plots you see in published astronomical work being created using the package. `Matplotlib` has amazing integration with other packages such as `Numpy`, `Scipy`, `Pandas`, and many others building around/with it.
#
# `Matplotlib`'s primary interface that is used within Python is `pyplot`, which makes `Matplotlib` work similarly to the plotting equivalent within the coding language `MATLAB`. We will delve into this structure further, but first let us import `Matplotlib.pyplot` using the standard naming alias, `plt`.

# %%
# Import matplotlib
import matplotlib.pyplot as plt # plt is the conventional name for matplotlib.pyplot

# %% [markdown]
# Let's start with the most basic plotting script, plotting the incident flux we just computed against the stellar effective temperature.

# %%
# Plot the data
plt.plot(nea_df['S_eff'], nea_df['st_teff'])

# Show the plot
plt.show()

# %% [markdown]
# Well that doesn't look pretty! All of the data is connected by lines instead of being discretized points. We can plot this as a scatter plot either by telling `plt.plot()` that we want markers or by using a different function, `plt.scatter()`.

# %%
# The 'o' argument makes large circles
plt.plot(nea_df['S_eff'], nea_df['st_teff'], 'o')

# Show the plot
plt.show()

# %%
# Using plt.scatter
plt.scatter(nea_df['S_eff'], nea_df['st_teff'])

plt.show()

# %% [markdown]
# `Matplotlib`'s default color scheme isn't very appealing, and you may instead want your data to be black. Most functions within `Matplotlib` allow the `c=''` argument to change the color (alias for `color=''`). You can also adjust the type of marker you are using `marker=''`, which is useful for when you are displaying different types of data on the same axes. A complete list of markers can be found at https://matplotlib.org/stable/api/markers_api.html
#
# We also need units on this plot! Others who look at your figures will not know what you are plotting unless you give them labels. We can add axis labels or even a title, although often in published worked plots don't have titles due to the existance of captions. `plt.xlabel()` and `plt.ylabel()` will do the trick! A cool feature of `Matplotlib` is your plots can includ LaTeX by using the usual LaTeX notation of `$Equation$`.

# %%
# Changing the color to black (k) and the marker to a triangle (^)
plt.scatter(nea_df['S_eff'], nea_df['st_teff'], c='k', marker='^')

# Note the dollar signs for LaTeX math mode
plt.xlabel(r'$S_{\rm eff}$ (Earth flux units)')
plt.ylabel(r'$T_{\rm eff}$ (K)')
plt.title('Exoplanet Insolation Flux')
plt.show()

# %% [markdown]
# One last thing... these axis are way too wide! We don't really care about the extremes of the data, so we can zoom in on the region of interest by using `plt.xlim()` and `plt.ylim()`. These functions take two values, the minimum and maximum of the axis range you want to display.

# %%
plt.scatter(nea_df['S_eff'], nea_df['st_teff'], c='k', marker='^')

# Note the dollar signs for LaTeX math mode
plt.xlabel(r'$S_{\rm eff}$ (Earth flux units)')
plt.ylabel(r'$T_{\rm eff}$ (K)')
plt.title('Exoplanet Insolation Flux')

# Put the limits here
plt.xlim(0, 100) # Only show planets with insolation fluxes between 0 and 100 Earth flux units
plt.ylim(3000, 7000) # Only show stars with effective temperatures between 3000 and 7000 K

plt.show()
